# %% [markdown]
# Welcome!
#
# This is a Kaggle notebook, where we will be doing our work for the first 3 or so weeks.
#
# I will write out brief summaries of what we cover in class -- and once we get there -- sample code and then make this document available shortly after class.
#
#
# We will do this each class day.

# %% [markdown]
# You will want to make a (free) account at www.kaggle.com
#
# I will post a link on the meeting chat for you to try out "live" if you'd like. Usually, I will save and post a copy of the file on the class website within about 30 minutes after class ends.
#
# To use, click on the link and then select "Copy and Edit" from the top right. This will make an editable copy in your own kaggle account. You can find your copy in the "code" section (click on the < > symbol on the left menu).

# %% [markdown]
# Syllabus -- our syllabus and course webpage can be found linked on Teams and https://hendrix-cs.github.io/csci150/

# %% [markdown]
# **Laptops/Tablets** in class:
#
# You are welcome to bring a laptop or tablet to class to use, but it is not required.
# * Benefits -- try code live -- I can see your mistakes
# * Drawbacks -- distraction

# %% [markdown]
# PyCharm -- starting in week 3 or 4, we will begin to use the free Python editor and project manager "PyCharm." We will spend time in class helping you get set up. It currently works with Mac/PC Laptops, but we have not yet been able to successfully get it to work on a Chromebook. The computers in the Snoddy Lab in the library (where you'll have Lab) all have Pycharm installed.
#
# There is nothing for you to do here now, but just as an FYI
#
# I can edit now **this is boldface**

# %% [markdown]
# Kaggle Notebooks: Cells
#
# Markdown
#
# Code

# %%
1 + 2

# %% [markdown]
# 1 + 2

# %%
now I want you to understand the nex ttopc

we are going to

# %% [markdown]
# What is "Computer Science?" What are we going to be talking about this semester?

# %% [markdown]
# Not the details of what is happening in the machine
#
# We are going to worry about the software side -- higher level/abstraction

# %% [markdown]
# How to use and process information

# %% [markdown]
# What do you need to do before Friday?
# * Survey -- linked on the course webpage
# * go to lab this afternoon/Thursday (online, on Teams)
# * any questions/concerns -- let me know and I'll be happy to talk with you
